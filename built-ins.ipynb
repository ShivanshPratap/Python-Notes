# %%
import builtins

print(dir(builtins))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %% [markdown]
# ### Short explanation of each builtins Function

# %% [raw]
# Built-in Functions:
#
# abs(): Returns the absolute value of a number.
# all(): Returns True if all elements in an iterable are true, otherwise False.
# any(): Returns True if any element in an iterable is true, otherwise False.
# ascii(): Returns a string containing a printable representation of an object.
# bin(): Converts an integer to a binary string.
# bool(): Converts a value to a Boolean (True or False).
# breakpoint(): Raises an ImportError if called; used for debugging.
# bytearray(): Returns a new array of bytes.
# bytes(): Returns a new bytes object.
# callable(): Checks if an object is callable (can be called as a function).
# chr(): Returns a string representing a character with the specified Unicode code.
# classmethod(): Returns a class method for a function.
# compile(): Compiles a source string into a code object or AST (Abstract Syntax Tree).
# complex(): Returns a complex number.
# delattr(): Deletes a named attribute from an object.
# dict(): Returns a new dictionary.
# dir(): Returns a list of names in the current local scope or a specified object.
# display(): Used in Jupyter notebooks to display objects.
# divmod(): Returns the quotient and remainder of dividing two numbers.
# enumerate(): Returns an iterator of tuples containing indices and values from an iterable.
# eval(): Evaluates a Python expression or evaluates a string of Python code.
# exec(): Executes a string of Python code or a code object.
# execfile(): Executes a file as a Python script.
# filter(): Filters elements from an iterable based on a given function.
# float(): Returns a floating-point number.
# format(): Formats a value based on a specified format string.
# frozenset(): Returns a new frozenset object.
# get_ipython(): Retrieves the current IPython InteractiveShell instance.
# getattr(): Returns the value of a named attribute of an object.
# globals(): Returns a dictionary representing the current global symbol table.
# hasattr(): Returns True if the object has the given named attribute, otherwise False.
# hash(): Returns the hash value of an object.
# help(): Displays information about objects.
# hex(): Converts an integer to a lowercase hexadecimal string.
# id(): Returns the identity of an object.
# input(): Reads input from the user through the console.
# int(): Returns an integer object or converts a string or number to an integer.
# isinstance(): Checks if an object is an instance of a specified type or class.
# issubclass(): Checks if a class is a subclass of a specified class.
# iter(): Returns an iterator object.
# len(): Returns the length (number of items) of an object.
# license(): Prints the Python software license details.
# list(): Returns a new list.
# locals(): Returns a dictionary representing the current local symbol table.
# map(): Applies a function to every item in an iterable and returns an iterator of the results.
# max(): Returns the largest item from a sequence or a set of arguments.
# memoryview(): Returns a memory view object.
# min(): Returns the smallest item from a sequence or a set of arguments.
# next(): Retrieves the next item from an iterator.
# object(): Returns a new featureless object.
# oct(): Converts an integer to an octal string.
# open(): Opens a file and returns a file object.
# ord(): Returns the Unicode code of a specified character.
# pow(): Raises a number to a specified power.
# print(): Prints output to the console.
# property(): Gets, sets, or deletes a property of an object.
# range(): Returns a sequence of numbers within a specified range.
# repr(): Returns a string containing a printable representation of an object.
# reversed(): Returns a reversed iterator of a sequence.
# round(): Rounds a number to a specified number of decimal places.
# runfile(): Executes a file as a Python script.
# set(): Returns a new set object.
# setattr(): Sets the value of a named attribute of an object.
# slice(): Returns a slice object representing a specified range of indices.
# sorted(): Returns a sorted version of a sequence or an iterable.
# staticmethod(): Returns a static method for a function.
# str(): Returns a string version of an object.
# sum(): Returns the sum of all items in a sequence or an iterable.
# super(): Returns a temporary object of the superclass.
# tuple(): Returns a new tuple object.
# type(): Returns the type of an object.
# vars(): Returns the __dict__ attribute of an object.
# zip(): Takes iterables as arguments and returns an iterator of tuples, where each tuple contains the i-th element from each of the argument sequences.
#
#     Built-in Exceptions:
#
# ArithmeticError: Base class for arithmetic errors.
# AssertionError: Raised when an assert statement fails.
# AttributeError: Raised when an attribute reference or assignment fails.
# BaseException: Base class for all exceptions.
# BlockingIOError: Raised when an operation would block on an IO stream.
# BrokenPipeError: Raised when a pipe is broken.
# BufferError: Raised when an operation on a buffer fails.
# BytesWarning: Base class for warnings about bytes and buffer-related operations.
# ChildProcessError: Raised when a child process encounters an error.
# ConnectionAbortedError: Raised when a connection is aborted by the peer.
# ConnectionError: Base class for connection-related errors.
# ConnectionRefusedError: Raised when a connection is refused by the peer.
# ConnectionResetError: Raised when a connection is reset by the peer.
# DeprecationWarning: Base class for warnings about deprecated features.
# EOFError: Raised when the input() function hits an end-of-file condition.
# Ellipsis: Represents a slice with an unspecified number of elements.
# EnvironmentError: Base class for errors related to the environment.
# Exception: Base class for all non-system-exiting exceptions.
# False: Boolean value representing false.
# FileExistsError: Raised when a file or directory already exists.
# FileNotFoundError: Raised when a file or directory is not found.
# FloatingPointError: Raised when a floating-point operation fails.
# FutureWarning: Base class for warnings about future behavior changes.
# GeneratorExit: Raised when a generator or coroutine is closed.
# IOError: Base class for I/O-related errors.
# ImportError: Raised when an import statement fails.
# ImportWarning: Base class for warnings about module imports.
# IndentationError: Base class for indentation-related errors.
# IndexError: Raised when a sequence subscript is out of range.
# InterruptedError: Raised when an interrupt-related system call is interrupted.
# IsADirectoryError: Raised when a directory is expected but a file is found.
# KeyError: Raised when a dictionary key is not found.
# KeyboardInterrupt: Raised when the user interrupts program execution (e.g., by pressing Ctrl+C).
# LookupError: Base class for lookup-related errors.
# MemoryError: Raised when an operation runs out of memory.
# ModuleNotFoundError: Raised when a module is not found.
# NameError: Raised when a local or global name is not found.
# None: Represents a null value.
# NotADirectoryError: Raised when a directory is expected but a non-directory is found.
# NotImplemented: Represents a placeholder for an abstract method or a method to be implemented in a subclass.
# NotImplementedError: Raised when an abstract method or a method to be implemented is not overridden.
# OSError: Base class for OS-related errors.
# OverflowError: Raised when the result of an arithmetic operation is too large to be expressed.
# PendingDeprecationWarning: Base class for warnings about features that will be deprecated in the future.
# PermissionError: Raised when an operation lacks the required permissions.
# ProcessLookupError: Raised when a process lookup fails.
# RecursionError: Raised when the maximum recursion depth is exceeded.
# ReferenceError: Raised when a weak reference object is used to access a garbage-collected referent.
# ResourceWarning: Base class for warnings about resource usage.
# RuntimeError: Raised when an error occurs that doesn't belong to any other category.
# RuntimeWarning: Base class for warnings about runtime behavior.
# StopAsyncIteration: Raised by an asynchronous iterator's __anext__() method to signal the end of iteration.
# StopIteration: Raised by an iterator's __next__() method to signal the end of iteration.
# SyntaxError: Raised when the syntax of a statement or expression is invalid.
# SyntaxWarning: Base class for warnings about dubious syntax.
# SystemError: Raised when an internal error in the interpreter is detected.
# SystemExit: Raised to exit the Python interpreter.
# TabError: Raised when indentation contains inconsistent use of tabs and spaces.
# TimeoutError: Raised when a system call exceeds the specified timeout duration.
# True: Boolean value representing true.
# TypeError: Raised when an operation or function is applied to an object of inappropriate type.
# UnboundLocalError: Raised when a local variable is referenced before it has been assigned a value.
# UnicodeDecodeError: Raised when a Unicode-related decoding error occurs.
# UnicodeEncodeError: Raised when a Unicode-related encoding error occurs.
# UnicodeError: Base class for Unicode-related errors.
# UnicodeTranslateError: Raised when a Unicode-related translation error occurs.
# UnicodeWarning: Base class for warnings about Unicode-related issues.
# UserWarning: Base class for user-generated warnings.
# ValueError: Raised when a function receives an argument of the correct type but an invalid value.
# Warning: Base class for warnings.
# WindowsError: Base class for Windows OS-related errors.
# ZeroDivisionError: Raised when division or modulo operation is performed with zero as the denominator.
